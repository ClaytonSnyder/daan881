# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import random

df = pd.read_csv('daan881_group4_dataset.final.cleaned.csv')

print(df.shape)
df.head()
# Out:
# (93697, 13)
#               cve                     date_reserved            date_published  \
# 0   CVE-2024-8969  2024-09-18 04:19:44.810000+00:00  2024-09-18T06:53:53.016Z
# 1   CVE-2024-8957  2024-09-17 19:08:48.129000+00:00  2024-09-17T20:08:25.588Z
# 2   CVE-2024-8956  2024-09-17 19:08:47.005000+00:00  2024-09-17T19:59:27.205Z
# 3   CVE-2024-8951  2024-09-17 15:24:05.559000+00:00  2024-09-17T20:00:08.078Z
# 4  CVE-2024-47059  2024-09-17 13:41:00.585000+00:00  2024-09-18T21:19:26.951Z
#
#    attack_vector  attack_complexity  attack_requirements  privileges_required  \
# 0            1.0                0.0                  NaN                  0.0
# 1            1.0                0.0                  NaN                  1.0
# 2            1.0                0.0                  NaN                  2.0
# 3            NaN                NaN                  NaN                  NaN
# 4            1.0                1.0                  NaN                  2.0
#
#    user_interaction  exploit_maturity  epss  percentile  cvss_score  \
# 0               0.0               NaN   NaN         NaN         6.5
# 1               0.0               NaN   NaN         NaN         7.2
# 2               0.0               NaN   NaN         NaN         9.1
# 3               NaN               NaN   NaN         NaN         5.3
# 4               0.0               NaN   NaN         NaN         0.0
#
#    cvss_severity
# 0            3.0
# 1            2.0
# 2            1.0
# 3            3.0
# 4            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93697 entries, 0 to 93696
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cve                  93697 non-null  object
#  1   date_reserved        93697 non-null  object
#  2   date_published       93697 non-null  object
#  3   attack_vector        42260 non-null  float64
#  4   attack_complexity    42260 non-null  float64
#  5   attack_requirements  626 non-null    float64
#  6   privileges_required  42260 non-null  float64
#  7   user_interaction     42260 non-null  float64
#  8   exploit_maturity     1797 non-null   float64
#  9   epss                 93506 non-null  float64
#  10  percentile           93506 non-null  float64
#  11  cvss_score           55284 non-null  float64
#  12  cvss_severity        55257 non-null  float64
# dtypes: float64(10), object(3)
# memory usage: 9.3+ MB

# %% [markdown]
# ## Converting datetimes
#
# A better way to analyze the dates is to use the number of days since the timestamp rather than the timestamp itself. This provides a numeric value that holds more information. For example, any high level vulnerability that was published long ago, we would want to prioritize highly. Notice that these values would change based on when the analysis occurs. So we should preprocess our data to convert these values from the raw data prior to feeding it into the model.

# %%
def parse_timestamp(ts):
    """
      Check if the timestamp already has timezone info
    """
    try:
        parsed_ts = pd.to_datetime(ts)
        if parsed_ts.tzinfo is None:
            # If timezone-naive, localize to UTC
            parsed_ts = parsed_ts.tz_localize('UTC')
        return parsed_ts
    except Exception as e:
        print(f"Error parsing timestamp: {ts} - {e}")
        return pd.NaT 

def reformat_dates(data, column, new_column_name):
    """
    Reformats dates to be an integer value in days since
    rather than a timestamp
    """
    # Strip fractional seconds using string manipulation
    data[column] = data[column].str.replace(r'\.\d+', '', regex=True)

    # Convert the cleaned column to datetime
    df[column] = df[column].apply(parse_timestamp)

    # Use a timezone-aware current time
    current_time = pd.Timestamp.now(tz="UTC")
    
    # Create a new column of the days since the original timestamp
    data[new_column_name] = (current_time - data[column]).dt.days


reformat_dates(df, "date_reserved", "days_since_reserved")
df = df.drop(columns=["date_reserved"])
reformat_dates(df, "date_published", "days_since_published")
df = df.drop(columns=["date_published"])

df["date_reserved_published_delta"] = df["days_since_reserved"] - df["days_since_published"]

df.head()
# Out:
#               cve  attack_vector  attack_complexity  attack_requirements  \
# 0   CVE-2024-8969            1.0                0.0                  NaN
# 1   CVE-2024-8957            1.0                0.0                  NaN
# 2   CVE-2024-8956            1.0                0.0                  NaN
# 3   CVE-2024-8951            NaN                NaN                  NaN
# 4  CVE-2024-47059            1.0                1.0                  NaN
#
#    privileges_required  user_interaction  exploit_maturity  epss  percentile  \
# 0                  0.0               0.0               NaN   NaN         NaN
# 1                  1.0               0.0               NaN   NaN         NaN
# 2                  2.0               0.0               NaN   NaN         NaN
# 3                  NaN               NaN               NaN   NaN         NaN
# 4                  2.0               0.0               NaN   NaN         NaN
#
#    cvss_score  cvss_severity  days_since_reserved  days_since_published  \
# 0         6.5            3.0                   59                    59
# 1         7.2            2.0                   59                    59
# 2         9.1            1.0                   59                    59
# 3         5.3            3.0                   59                    59
# 4         0.0            NaN                   60                    58
#
#    date_reserved_published_delta
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              2

# %% [markdown]
# ## Adding Heuristic/Rules
#
# Since we need supervised data. We need to come up with an algorithm that outputs a priority score which will be our target variable for our model. To do this we will normalize our numeric data between 0 and 1 and apply a weight to each of the features to generate a priority score. First, we must normalize the data.

# %%
data_copy = df.copy()
data_copy.head()
# Out:
#               cve  attack_vector  attack_complexity  attack_requirements  \
# 0   CVE-2024-8969            1.0                0.0                  NaN
# 1   CVE-2024-8957            1.0                0.0                  NaN
# 2   CVE-2024-8956            1.0                0.0                  NaN
# 3   CVE-2024-8951            NaN                NaN                  NaN
# 4  CVE-2024-47059            1.0                1.0                  NaN
#
#    privileges_required  user_interaction  exploit_maturity  epss  percentile  \
# 0                  0.0               0.0               NaN   NaN         NaN
# 1                  1.0               0.0               NaN   NaN         NaN
# 2                  2.0               0.0               NaN   NaN         NaN
# 3                  NaN               NaN               NaN   NaN         NaN
# 4                  2.0               0.0               NaN   NaN         NaN
#
#    cvss_score  cvss_severity  days_since_reserved  days_since_published  \
# 0         6.5            3.0                   59                    59
# 1         7.2            2.0                   59                    59
# 2         9.1            1.0                   59                    59
# 3         5.3            3.0                   59                    59
# 4         0.0            NaN                   60                    58
#
#    date_reserved_published_delta
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              2

# %%
def generate_priority_score(row, current_data):
    score = 0

    # Base initial high weights to epss and cvss
    if row["cvss_score"] > 0 and row["epss"] > 0:
        # If cvss and epss are both defined
        # take the average
        score += (row["cvss_score"] + (10 * row["epss"]))/2
        score += ((5 - row["cvss_severity"]) + ((10 * row["percentile"])/2))/2
    elif row["cvss_score"] > 0:
        # CVSS score which has been normalized from 0-10, so we will multiple by 5
        # to distinguish between cves with the same severity
        score += row["cvss_score"]

        # We should prioritze high servity first, this is a range from LOW (4) - Critical (0)
        # So we will subtract 5 and take half as the weight 
        score += 5 - row["cvss_severity"]
    elif row["epss"] > 0:
        # The overall chance of explortation is a probability. To make it equivalent
        # to the cvss score we will multiple by 10
        score += 10 * row["epss"]

        # The percentile is how likely it is to be exploited, 0-1
        # to make this equivalent to cvss_severity we will multiple by 10, divide by 2.
        score += (10 * row["percentile"])/2

    # Prioritize high severity that have been sitting for a while
    max_days_since_published = current_data["days_since_reserved"].max()

    if score > 10 and max_days_since_published > 0 and row["days_since_reserved"] > 0:
        published_days_ratio = row["days_since_reserved"]/max_days_since_published
        score += 5 * float(int(10 * published_days_ratio))

    # Prioritize items that quickly were published after being identified
    max_days_reserved_published_delta = current_data["date_reserved_published_delta"].max()

    if max_days_reserved_published_delta > 0 and row["date_reserved_published_delta"] > 0:
        delta_ratio = row["date_reserved_published_delta"]/max_days_reserved_published_delta
        score += 10 * delta_ratio

    # if there is a network vector then add more weight
    # than any other case
    if row["attack_vector"] == 1:
        score += 1
    else: 
        score += 0.5

    # if the attack complexity is LOW then 1,
    # if it is high then 0.5
    if row["attack_complexity"] == 0:
        score += 1
    else: 
        score += 0.5
    
    # if the attack requirements is None then 1,
    # if it is high then 0.5
    if row["attack_requirements"] == 0:
        score += 1
    else: 
        score += 0.5

    # if the No privledges are required then 1,
    # If low privs required then 0.5
    # if high privs required then 0.25
    if row["privileges_required"] == 2:
        score += 1
    elif row["privileges_required"] == 0:
        score += 0.5
    else: 
        score += 0.25

    # if the No user interaction is required then 1,
    # If passive then 0.5
    # if required or active then 0.25
    if row["privileges_required"] == 0:
        score += 1
    elif row["privileges_required"] == 3:
        score += 0.5
    else: 
        score += 0.25

    # if exploit maturity is high or not defined then 0,
    # if exploit maturity is functional then 0.5,
    # if proof_of_concept or unproven then 0.25
    if row["exploit_maturity"] == 0 or row["exploit_maturity"] == 3:
        score += 1
    elif row["exploit_maturity"] == 3:
        score += 0.5
    else: 
        score += 0.25

    return score

# %%
number_of_train_groups = 1000
number_of_validation_groups = 100
max_number_of_cves = 500
min_number_of_cves = 100

train_dataset_list = []
val_dataset_list = []

for group_number in range(number_of_train_groups + number_of_validation_groups):
    number_of_cves = random.randint(min_number_of_cves, max_number_of_cves)
    random_rows = data_copy.sample(n=number_of_cves)
    random_rows["priority_score"] = random_rows.apply(generate_priority_score, current_data=data_copy, axis=1)
    random_rows = random_rows.sort_values(by="priority_score", ascending=False)
    random_rows["group_id"] = group_number+1

    if (group_number+1) > (number_of_train_groups):
        val_dataset_list.append(random_rows)
    else:
        train_dataset_list.append(random_rows)

    print(random_rows.head(n=5))

train_dataset = pd.concat(train_dataset_list)
val_dataset = pd.concat(val_dataset_list)
# Out:
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 92774  CVE-2021-22205            1.0                0.0                  NaN
# 88668  CVE-2021-27964            NaN                NaN                  NaN
# 38881  CVE-2023-33568            NaN                NaN                  NaN
# 80915  CVE-2021-39014            1.0                0.0                  NaN
# 69360  CVE-2022-26843            1.0                1.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 92774                  2.0               0.0               NaN  0.97358
# 88668                  NaN               NaN               NaN  0.69570
# 38881                  NaN               NaN               NaN  0.52799
# 80915                  0.0               0.0               NaN  0.00050
# 69360                  2.0               1.0               NaN  0.00201
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 92774     0.99922        10.0            1.0                 1411
# 88668     0.98057         NaN            NaN                 1352
# 38881     0.97628         NaN            NaN                  544
# 80915     0.19731         6.4            3.0                 1187
# 69360     0.58105         8.3            2.0                  982
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 92774                  1302                            109       64.176359
# 88668                  1352                              0       59.109850
# 38881                   522                             22       27.574869
# 80915                   497                            690       14.075887
# 69360                   638                            344       13.170296
#
#        group_id
# 92774         1
# 88668         1
# 38881         1
# 80915         1
# 69360         1
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 45948  CVE-2023-26009            1.0                0.0                  NaN
# 92897  CVE-2021-22573            1.0                0.0                  NaN
# 42230  CVE-2023-29486            1.0                0.0                  NaN
# 93367  CVE-2021-21921            1.0                0.0                  NaN
# 90204  CVE-2021-25955            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
#
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 88938                  1127                            236       63.750097
# 73233                   275                            765       15.265357
# 88979                   927                            439       14.368141
# 51502                   379                            330       14.199657
# 50590                   486                            213       13.629468
#
#        group_id
# 88938         8
# 73233         8
# 88979         8
# 51502         8
# 50590         8
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 79035  CVE-2021-41653            NaN                NaN                  NaN
# 93374  CVE-2021-21914            1.0                0.0                  NaN
# 93627  CVE-2021-21850            1.0                0.0                  NaN
# 75116  CVE-2022-21940            1.0                1.0                  NaN
# 66171  CVE-2022-30311            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 79035                  NaN               NaN               NaN  0.94717
# 93374                  2.0               0.0               NaN  0.00271
# 93627                  2.0               1.0               NaN  0.00228
# 75116                  2.0               1.0               NaN  0.00082
# 66171                  2.0               0.0               NaN  0.00198
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 79035     0.99296         NaN            NaN                 1146
# 93374     0.68177         9.8            1.0                 1412
# 93627     0.61158         8.8            2.0                 1412
# 75116     0.35753         7.5            2.0                 1066
# 66171     0.57725         9.8            1.0                  925
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 79035                  1099                             47       57.035942
# 93374                   946                            466       16.082659
# 93627                  1178                            234       13.180127
# 75116                   645                            421       12.778037
# 66171                   887                             38       12.635553
#
#        group_id
# 79035         9
# 93374         9
# 93627         9
# 75116         9
# 66171         9
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 68711  CVE-2022-27487            1.0                0.0                  NaN
# 87124  CVE-2021-30281            2.0                0.0                  NaN
# 90225  CVE-2021-25985            2.0                0.0                  NaN
# 3125    CVE-2024-6917            1.0                0.0                  0.0
# 92301   CVE-2021-3059            1.0                1.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 68711                  0.0               0.0               NaN  0.00177
# 87124                  2.0               0.0               NaN  0.00044
# 90225                  2.0               1.0               NaN  0.00244
# 3125                   2.0               0.0               NaN  0.00090
# 92301                  2.0               0.0               NaN  0.00120
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 68711     0.55216         8.3            2.0                  970
# 87124     0.13301         8.4            2.0                 1319
# 90225     0.64665         7.8            2.0                 1394
# 3125      0.39030        10.0            1.0                  120
# 92301     0.46984         8.1            2.0                 1410
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 68711                   584                            386       14.159138
# 87124                   886                            433       12.754056
# 90225                  1096                            298       12.744438
# 3125                     95                             25       12.666124
# 92301                  1101                            309       12.527998
#
#        group_id
# 68711        10
# 87124        10
# 90225        10
# 3125         10
# 92301        10
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 88703  CVE-2021-27915            1.0                0.0                  NaN
# 71962  CVE-2022-24086            1.0                0.0                  NaN
# 44659  CVE-2023-27524            1.0                1.0                  NaN
# 27425  CVE-2023-46805            NaN                NaN                  NaN
# 51349  CVE-2022-47036            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 88703                  0.0               1.0               NaN      NaN
# 71962                  2.0               0.0               NaN  0.22602
# 44659                  2.0               0.0               NaN  0.97060
# 27425                  NaN               NaN               NaN  0.95023
# 51349                  2.0               0.0               NaN  0.00043
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 88703         NaN         7.6            2.0                 1354
# 71962     0.96602         9.8            1.0                 1024
# 44659     0.99802         8.9            2.0                  625
# 27425     0.99350         8.2            2.0                  386
# 51349     0.09608         9.8            1.0                  705
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 88703                    60                           1294       69.470818
# 71962                  1003                             21       49.601284
# 44659                   571                             54       37.199537
# 27425                   308                             78       25.664826
# 51349                   243                            462       14.577294
#
#        group_id
# 88703        11
# 71962        11
# 44659        11
# 27425        11
# 51349        11
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 37580  CVE-2023-34960            NaN                NaN                  NaN
# 85349  CVE-2021-32858            1.0                0.0                  NaN
# 75041  CVE-2022-22034            NaN                NaN                  NaN
# 85212  CVE-2021-33020            1.0                0.0                  NaN
# 60019  CVE-2022-37425            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 37580                  NaN               NaN               NaN  0.90052
# 85349                  2.0               1.0               NaN  0.00068
# 75041                  NaN               NaN               NaN  0.33833
# 85212                  2.0               0.0               NaN  0.00152
# 60019                  0.0               0.0               NaN  0.00109
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 37580     0.98865         NaN            NaN                  528
# 85349     0.30785         6.1            3.0                 1284
# 75041     0.97141         7.8            2.0                 1066
# 85212     0.51944         8.2            2.0                 1283
# 60019     0.44745         9.9            1.0                  834
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 37580                   473                             55       31.607372
# 85349                   635                            649       13.648304
# 75041                   857                            209       13.324078
# 85212                   959                            324       13.315122
# 60019                   749                             85       12.956045
#
#        group_id
# 37580        12
# 85349        12
# 75041        12
# 85212        12
# 60019        12
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 69980  CVE-2022-26134            NaN                NaN                  NaN
# 60208  CVE-2022-37042            NaN                NaN                  NaN
# 51049  CVE-2023-21716            NaN                NaN                  NaN
# 90193  CVE-2021-25992            1.0                0.0                  NaN
# 83378  CVE-2021-35689            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 69980                  NaN               NaN               NaN  0.97395
# 60208                  NaN               NaN               NaN  0.97528
# 51049                  NaN               NaN               NaN  0.35983
# 90193                  2.0               0.0               NaN  0.00236
# 83378                  2.0               0.0               NaN  0.00589
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 69980     0.99936         NaN            NaN                  995
# 60208     0.99994         NaN            NaN                  838
# 51049     0.97213         9.8            1.0                  703
# 90193     0.61789         9.8            1.0                 1394
# 83378     0.78505         9.8            1.0                 1237
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 69980                   896                             99       52.722359
# 60208                   827                             11       42.084284
# 51049                   640                             63       33.847876
# 90193                  1010                            384       15.311544
# 83378                   996                            241       14.683897
#
#        group_id
# 69980        13
# 60208        13
# 51049        13
# 90193        13
# 83378        13
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 86083  CVE-2021-31755            NaN                NaN                  NaN
# 89307  CVE-2021-27162            NaN                NaN                  NaN
# 92057  CVE-2021-23449            1.0                0.0                  NaN
# 90191  CVE-2021-25994            1.0                0.0                  NaN
# 44916   CVE-2023-1082            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 86083                  NaN               NaN               NaN  0.97175
# 89307                  NaN               NaN               NaN  0.81177
# 92057                  2.0               0.0               1.0  0.00797
# 90191                  2.0               1.0               NaN  0.00241
# 44916                  0.0               0.0               NaN  0.00052
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 86083     0.99847         NaN            NaN                 1303
# 89307     0.98401         NaN            NaN                 1375
# 92057     0.81885         9.8            1.0                 1408
# 90191     0.64383         8.8            2.0                 1394
# 44916     0.21101         8.8            2.0                  627
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 86083                  1288                             15       62.071374
# 89307                  1374                              1       60.295185
# 92057                  1124                            284       15.098499
# 90191                  1048                            346       14.094116
# 44916                   221                            406       13.698712
#
#        group_id
# 86083        14
# 89307        14
# 92057        14
# 90191        14
# 44916        14
#                   cve  attack_vector  attack_complexity  attack_requirements  \
#
1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 90000                  NaN               NaN               NaN  0.97409
# 75659                  NaN               NaN               NaN  0.97409
# 49788                  2.0               0.0               NaN  0.95987
# 26651                  2.0               0.0               NaN  0.91871
# 50501                  2.0               0.0               NaN  0.00189
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 90000     0.99943         NaN            NaN                 1391
# 75659     0.99944         NaN            NaN                 1081
# 49788     0.99515         9.8            1.0                  688
# 26651     0.98983         9.8            1.0                  374
# 50501     0.56701         9.8            1.0                  699
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 90000                  1174                            217       63.601433
# 75659                  1070                             11       52.069884
# 49788                   637                             51       38.566407
# 26651                   365                              9       28.035039
# 50501                   395                            304       14.587198
#
#        group_id
# 90000        18
# 75659        18
# 49788        18
# 26651        18
# 50501        18
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 56518  CVE-2022-41622            1.0                0.0                  NaN
# 79715  CVE-2021-40790            2.0                0.0                  NaN
# 45572  CVE-2023-26418            2.0                0.0                  NaN
# 73611   CVE-2021-4201            1.0                0.0                  NaN
# 68543  CVE-2022-26423            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 56518                  2.0               1.0               NaN  0.47272
# 79715                  2.0               1.0               0.0  0.00136
# 45572                  2.0               1.0               NaN  0.36399
# 73611                  2.0               1.0               NaN  0.00489
# 68543                  2.0               0.0               NaN  0.00172
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 56518     0.97508         8.8            2.0                  777
# 79715     0.49637         5.5            3.0                 1164
# 45572     0.97225         7.8            2.0                  633
# 73611     0.76341         9.6            1.0                 1045
# 68543     0.54611         8.2            2.0                  968
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 56518                   710                             67       40.199441
# 79715                   436                            728       14.660364
# 45572                   584                             49       13.514887
# 73611                  1005                             40       13.030373
# 68543                   756                            212       12.550083
#
#        group_id
# 56518        19
# 79715        19
# 45572        19
# 73611        19
# 68543        19
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 86088  CVE-2021-31761            NaN                NaN                  NaN
# 43696  CVE-2023-28451            1.0                0.0                  NaN
# 63      CVE-2024-8767            NaN                NaN                  NaN
# 70165  CVE-2022-21165            1.0                0.0                  NaN
# 83454  CVE-2021-35498            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 86088                  NaN               NaN               NaN  0.95179
# 43696                  2.0               0.0               NaN      NaN
# 63                     NaN               NaN               NaN      NaN
# 70165                  2.0               0.0               NaN  0.00579
# 83454                  2.0               0.0               NaN  0.00244
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 86088     0.99372         NaN            NaN                 1303
# 43696         NaN         7.5            2.0                  612
# 63            NaN         9.9            1.0                   64
# 70165     0.78279         9.8            1.0                  996
# 83454     0.64665         9.8            1.0                 1241
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 86088                  1300                              3       61.758805
# 43696                    59                            553       38.611524
# 63                       60                              4       16.179740
# 70165                   810                            186       14.268825
# 83454                  1129                            112       13.361539
#
#        group_id
# 86088        20
# 43696        20
# 63           20
# 70165        20
# 83454        20
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 85337  CVE-2021-32819            1.0                1.0                  NaN
# 58084  CVE-2022-39986            NaN                NaN                  NaN
# 43769  CVE-2023-28343            NaN                NaN                  NaN
# 77535  CVE-2022-20711            1.0                0.0                  NaN
# 51312  CVE-2022-46945            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 85337                  2.0               1.0               NaN  0.80251
# 58084                  NaN               NaN               NaN  0.88675
# 43769                  NaN               NaN               NaN  0.93313
# 77535                  2.0               0.0               NaN  0.00490
# 51312                  0.0               0.0               NaN  0.00151
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 85337     0.98358         8.0            2.0                 1284
# 58084     0.98779         NaN            NaN                  802
# 43769     0.99134         NaN            NaN                  613
# 77535     0.76352        10.0            1.0                 1110
# 51312     0.51735         9.1            1.0                  705
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 85337                  1282                              2       60.486370
# 58084                   473                            329       43.502547
# 43769                   613                              0       36.538000
# 77535                  1009                            101       13.684229
# 51312                   540                            165       13.327691
#
#        group_id
# 85337        21
# 58084        21
# 43769        21
# 77535        21
# 51312        21
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 9384    CVE-2024-4577            1.0                0.0                  NaN
# 80223  CVE-2021-39822            2.0                0.0                  NaN
# 68700  CVE-2022-27596            1.0                0.0                  NaN
# 71036  CVE-2022-24809            1.0                0.0                  NaN
# 75966  CVE-2021-44159            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 9384                   2.0               0.0               NaN  0.96320
# 80223                  2.0               1.0               0.0  0.00164
# 68700                  2.0               0.0               NaN  0.00373
# 71036                  0.0               0.0               NaN  0.00044
# 75966                  2.0               0.0               NaN  0.05847
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 9384      0.99582         9.8            1.0                  193
# 80223     0.53499         7.8            2.0                 1180
# 68700     0.72979         9.8            1.0                  970
# 71036     0.10921         6.5            3.0                 1009
# 75966     0.93542         9.8            1.0                 1089
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 9384                    159                             34       23.458338
# 80223                   485                            695       16.162961
# 68700                   656                            314       15.077697
# 71036                   213                            796       14.693441
# 75966                  1062                             27       13.731643
#
#        group_id
# 9384         22
# 80223        22
# 68700        22
# 71036        22
# 75966        22
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 21819  CVE-2024-21683            1.0                0.0                  NaN
# 71080  CVE-2022-24786            1.0                0.0                  NaN
# 56094  CVE-2022-42492            1.0                0.0                  NaN
# 26008  CVE-2023-39226            1.0                0.0                  NaN
# 88273  CVE-2021-28505            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 21819                  2.0               1.0               NaN  0.94425
# 71080                  2.0               0.0               NaN  0.00803
# 56094                  2.0               0.0               NaN  0.00237
# 26008                  2.0               0.0               NaN  0.00758
# 88273                  2.0               0.0               NaN  0.00078
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 21819     0.99255         8.8            2.0                  320
# 71080     0.81962         9.8            1.0                 1010
# 56094     0.61884         9.8            1.0                  770
# 26008     0.81364         9.8            1.0                  366
# 88273     0.34585         7.5            2.0                 1341
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 21819                   178                            142       28.158387
# 71080                   955                             55       13.398122
# 56094                   659                            111       13.284229
# 26008                   351                             15       13.083524
# 88273                   946                            395       13.055328
#
#        group_id
# 21819        23
# 71080        23
# 56094        23
# 26008        23
# 88273        23
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 61021   CVE-2022-2487            3.0                0.0                  NaN
# 14738  CVE-2024-28987            1.0                0.0                  NaN
# 64116  CVE-2022-32524            1.0                0.0                  NaN
# 85352  CVE-2021-32855            1.0                0.0                  NaN
# 71187  CVE-2022-24903            1.0                1.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 61021                  0.0               0.0               NaN  0.97409
# 14738                  2.0               0.0               NaN  0.94156
# 64116                  2.0               0.0               NaN  0.00441
# 85352                  2.0               1.0               NaN  0.00079
# 71187                  2.0               0.0               NaN  0.19099
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 61021     0.99944         8.0            2.0                  850
# 14738     0.99226         9.1            1.0                  247
# 64116     0.75129         9.8            1.0                  893
# 85352     0.34790         6.1            3.0                 1284
# 71187     0.96347         8.1            2.0                 1010
#
#        days_since_published  date_reserved_published_delta  priority_score  \
#
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 87743  CVE-2021-29442            1.0                0.0                  NaN
# 58167  CVE-2022-39952            1.0                0.0                  NaN
# 83135  CVE-2021-36021            1.0                0.0                  NaN
# 88966  CVE-2021-27429            2.0                1.0                  NaN
# 77058  CVE-2021-43361            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 87743                  2.0               0.0               NaN  0.96984
# 58167                  2.0               0.0               NaN  0.94687
# 83135                  1.0               0.0               0.0  0.00184
# 88966                  2.0               0.0               NaN  0.00043
# 77058                  2.0               0.0               NaN  0.00142
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 87743     0.99773         8.6            2.0                 1327
# 58167     0.99291         9.8            1.0                  803
# 83135     0.56013         7.2            2.0                 1234
# 88966     0.10104         7.4            2.0                 1365
# 77058     0.50601         9.9            1.0                 1108
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 87743                  1298                             29       62.359138
# 58167                   638                            165       44.343391
# 83135                   437                            797       16.435176
# 88966                   361                           1004       15.919434
# 77058                   779                            329       14.668222
#
#        group_id
# 87743      1098
# 58167      1098
# 83135      1098
# 88966      1098
# 77058      1098
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 61423  CVE-2022-35914            NaN                NaN                  NaN
# 68484  CVE-2022-27925            NaN                NaN                  NaN
# 37589  CVE-2023-34634            NaN                NaN                  NaN
# 19859  CVE-2024-23897            1.0                0.0                  NaN
# 27250  CVE-2023-47075            2.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 61423                  NaN               NaN               NaN  0.97412
# 68484                  NaN               NaN               NaN  0.94565
# 37589                  NaN               NaN               NaN  0.92314
# 19859                  2.0               0.0               NaN  0.97026
# 27250                  2.0               1.0               0.0  0.60751
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 61423     0.99946         NaN            NaN                  855
# 68484     0.99276         NaN            NaN                  967
# 37589     0.99026         NaN            NaN                  528
# 19859     0.99789         9.8            1.0                  298
# 27250     0.97844         7.8            2.0                  382
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 61423                   789                             66       47.479206
# 68484                   940                             27       46.871043
# 37589                   473                             55       31.841622
# 19859                   296                              2       28.260895
# 27250                   339                             43       25.453353
#
#        group_id
# 61423      1099
# 68484      1099
# 37589      1099
# 19859      1099
# 27250      1099
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 83532  CVE-2021-35394            NaN                NaN                  NaN
# 82264  CVE-2021-37346            NaN                NaN                  NaN
# 76044  CVE-2021-44077            NaN                NaN                  NaN
# 35923  CVE-2023-37146            NaN                NaN                  NaN
# 29297  CVE-2023-44359            2.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 83532                  NaN               NaN               NaN  0.96648
# 82264                  NaN               NaN               NaN  0.74522
# 76044                  NaN               NaN               NaN  0.97404
# 35923                  NaN               NaN               NaN  0.55566
# 29297                  2.0               1.0               0.0  0.78240
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 83532     0.99674         NaN            NaN                 1242
# 82264     0.98186         NaN            NaN                 1214
# 76044     0.99941         NaN            NaN                 1092
# 35923     0.97702         NaN            NaN                  507
# 29297     0.98288         7.8            2.0                  414
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 83532                  1188                             54       57.299987
# 82264                  1191                             23       54.782504
# 76044                  1083                              9       52.054364
# 35923                   498                              9       27.758614
# 29297                   366                             48       26.376077
#
#        group_id
# 83532      1100
# 82264      1100
# 76044      1100
# 35923      1100
# 29297      1100

# %%
train_dataset.to_csv("daan881_group4_dataset.train.csv", index=False)
val_dataset.to_csv("daan881_group4_dataset.val.csv", index=False)
