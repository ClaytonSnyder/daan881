# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
import random

df = pd.read_csv('daan881_group4_dataset.final.cleaned.csv')

print(df.shape)
df.head()
# Out:
# (93697, 13)
#               cve                     date_reserved            date_published  \
# 0   CVE-2024-8969  2024-09-18 04:19:44.810000+00:00  2024-09-18T06:53:53.016Z
# 1   CVE-2024-8957  2024-09-17 19:08:48.129000+00:00  2024-09-17T20:08:25.588Z
# 2   CVE-2024-8956  2024-09-17 19:08:47.005000+00:00  2024-09-17T19:59:27.205Z
# 3   CVE-2024-8951  2024-09-17 15:24:05.559000+00:00  2024-09-17T20:00:08.078Z
# 4  CVE-2024-47059  2024-09-17 13:41:00.585000+00:00  2024-09-18T21:19:26.951Z
#
#    attack_vector  attack_complexity  attack_requirements  privileges_required  \
# 0            1.0                0.0                  NaN                  0.0
# 1            1.0                0.0                  NaN                  1.0
# 2            1.0                0.0                  NaN                  2.0
# 3            NaN                NaN                  NaN                  NaN
# 4            1.0                1.0                  NaN                  2.0
#
#    user_interaction  exploit_maturity  epss  percentile  cvss_score  \
# 0               0.0               NaN   NaN         NaN         6.5
# 1               0.0               NaN   NaN         NaN         7.2
# 2               0.0               NaN   NaN         NaN         9.1
# 3               NaN               NaN   NaN         NaN         5.3
# 4               0.0               NaN   NaN         NaN         0.0
#
#    cvss_severity
# 0            3.0
# 1            2.0
# 2            1.0
# 3            3.0
# 4            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93697 entries, 0 to 93696
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cve                  93697 non-null  object
#  1   date_reserved        93697 non-null  object
#  2   date_published       93697 non-null  object
#  3   attack_vector        42260 non-null  float64
#  4   attack_complexity    42260 non-null  float64
#  5   attack_requirements  626 non-null    float64
#  6   privileges_required  42260 non-null  float64
#  7   user_interaction     42260 non-null  float64
#  8   exploit_maturity     1797 non-null   float64
#  9   epss                 93506 non-null  float64
#  10  percentile           93506 non-null  float64
#  11  cvss_score           55284 non-null  float64
#  12  cvss_severity        55257 non-null  float64
# dtypes: float64(10), object(3)
# memory usage: 9.3+ MB

# %% [markdown]
# ## Converting datetimes
#
# A better way to analyze the dates is to use the number of days since the timestamp rather than the timestamp itself. This provides a numeric value that holds more information. For example, any high level vulnerability that was published long ago, we would want to prioritize highly. Notice that these values would change based on when the analysis occurs. So we should preprocess our data to convert these values from the raw data prior to feeding it into the model.

# %%
def parse_timestamp(ts):
    """
      Check if the timestamp already has timezone info
    """
    try:
        parsed_ts = pd.to_datetime(ts)
        if parsed_ts.tzinfo is None:
            # If timezone-naive, localize to UTC
            parsed_ts = parsed_ts.tz_localize('UTC')
        return parsed_ts
    except Exception as e:
        print(f"Error parsing timestamp: {ts} - {e}")
        return pd.NaT 

def reformat_dates(data, column, new_column_name):
    """
    Reformats dates to be an integer value in days since
    rather than a timestamp
    """
    # Strip fractional seconds using string manipulation
    data[column] = data[column].str.replace(r'\.\d+', '', regex=True)

    # Convert the cleaned column to datetime
    df[column] = df[column].apply(parse_timestamp)

    # Use a timezone-aware current time
    current_time = pd.Timestamp.now(tz="UTC")
    
    # Create a new column of the days since the original timestamp
    data[new_column_name] = (current_time - data[column]).dt.days


reformat_dates(df, "date_reserved", "days_since_reserved")
df = df.drop(columns=["date_reserved"])
reformat_dates(df, "date_published", "days_since_published")
df = df.drop(columns=["date_published"])

df["date_reserved_published_delta"] = df["days_since_reserved"] - df["days_since_published"]

df.head()
# Out:
#               cve  attack_vector  attack_complexity  attack_requirements  \
# 0   CVE-2024-8969            1.0                0.0                  NaN
# 1   CVE-2024-8957            1.0                0.0                  NaN
# 2   CVE-2024-8956            1.0                0.0                  NaN
# 3   CVE-2024-8951            NaN                NaN                  NaN
# 4  CVE-2024-47059            1.0                1.0                  NaN
#
#    privileges_required  user_interaction  exploit_maturity  epss  percentile  \
# 0                  0.0               0.0               NaN   NaN         NaN
# 1                  1.0               0.0               NaN   NaN         NaN
# 2                  2.0               0.0               NaN   NaN         NaN
# 3                  NaN               NaN               NaN   NaN         NaN
# 4                  2.0               0.0               NaN   NaN         NaN
#
#    cvss_score  cvss_severity  days_since_reserved  days_since_published  \
# 0         6.5            3.0                   85                    85
# 1         7.2            2.0                   86                    86
# 2         9.1            1.0                   86                    86
# 3         5.3            3.0                   86                    86
# 4         0.0            NaN                   86                    85
#
#    date_reserved_published_delta
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              1

# %% [markdown]
# ## Adding Heuristic/Rules
#
# Since we need supervised data. We need to come up with an algorithm that outputs a priority score which will be our target variable for our model. To do this we will normalize our numeric data between 0 and 1 and apply a weight to each of the features to generate a priority score. First, we must normalize the data.

# %%
data_copy = df.copy()
data_copy.head()
# Out:
#               cve  attack_vector  attack_complexity  attack_requirements  \
# 0   CVE-2024-8969            1.0                0.0                  NaN
# 1   CVE-2024-8957            1.0                0.0                  NaN
# 2   CVE-2024-8956            1.0                0.0                  NaN
# 3   CVE-2024-8951            NaN                NaN                  NaN
# 4  CVE-2024-47059            1.0                1.0                  NaN
#
#    privileges_required  user_interaction  exploit_maturity  epss  percentile  \
# 0                  0.0               0.0               NaN   NaN         NaN
# 1                  1.0               0.0               NaN   NaN         NaN
# 2                  2.0               0.0               NaN   NaN         NaN
# 3                  NaN               NaN               NaN   NaN         NaN
# 4                  2.0               0.0               NaN   NaN         NaN
#
#    cvss_score  cvss_severity  days_since_reserved  days_since_published  \
# 0         6.5            3.0                   85                    85
# 1         7.2            2.0                   86                    86
# 2         9.1            1.0                   86                    86
# 3         5.3            3.0                   86                    86
# 4         0.0            NaN                   86                    85
#
#    date_reserved_published_delta
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              1

# %%
def generate_priority_score(row, current_data):
    score = 0

    # Base initial high weights to epss and cvss
    if row["cvss_score"] > 0 and row["epss"] > 0:
        # If cvss and epss are both defined
        # take the average
        score += (row["cvss_score"] + (10 * row["epss"]))/2
        score += ((5 - row["cvss_severity"]) + ((10 * row["percentile"])/2))/2
    elif row["cvss_score"] > 0:
        # CVSS score which has been normalized from 0-10, so we will multiple by 5
        # to distinguish between cves with the same severity
        score += row["cvss_score"]

        # We should prioritze high servity first, this is a range from LOW (4) - Critical (0)
        # So we will subtract 5 and take half as the weight 
        score += 5 - row["cvss_severity"]
    elif row["epss"] > 0:
        # The overall chance of explortation is a probability. To make it equivalent
        # to the cvss score we will multiple by 10
        score += 10 * row["epss"]

        # The percentile is how likely it is to be exploited, 0-1
        # to make this equivalent to cvss_severity we will multiple by 10, divide by 2.
        score += (10 * row["percentile"])/2

    # Prioritize high severity that have been sitting for a while
    max_days_since_published = current_data["days_since_reserved"].max()

    if score > 10 and max_days_since_published > 0 and row["days_since_reserved"] > 0:
        published_days_ratio = row["days_since_reserved"]/max_days_since_published
        score += 5 * float(int(10 * published_days_ratio))

    # Prioritize items that quickly were published after being identified
    max_days_reserved_published_delta = current_data["date_reserved_published_delta"].max()

    if max_days_reserved_published_delta > 0 and row["date_reserved_published_delta"] > 0:
        delta_ratio = row["date_reserved_published_delta"]/max_days_reserved_published_delta
        score += 10 * delta_ratio

    # if there is a network vector then add more weight
    # than any other case
    if row["attack_vector"] == 1:
        score += 1
    else: 
        score += 0.5

    # if the attack complexity is LOW then 1,
    # if it is high then 0.5
    if row["attack_complexity"] == 0:
        score += 1
    else: 
        score += 0.5
    
    # if the attack requirements is None then 1,
    # if it is high then 0.5
    if row["attack_requirements"] == 0:
        score += 1
    else: 
        score += 0.5

    # if the No privledges are required then 1,
    # If low privs required then 0.5
    # if high privs required then 0.25
    if row["privileges_required"] == 2:
        score += 1
    elif row["privileges_required"] == 0:
        score += 0.5
    else: 
        score += 0.25

    # if the No user interaction is required then 1,
    # If passive then 0.5
    # if required or active then 0.25
    if row["privileges_required"] == 0:
        score += 1
    elif row["privileges_required"] == 3:
        score += 0.5
    else: 
        score += 0.25

    # if exploit maturity is high or not defined then 0,
    # if exploit maturity is functional then 0.5,
    # if proof_of_concept or unproven then 0.25
    if row["exploit_maturity"] == 0 or row["exploit_maturity"] == 3:
        score += 1
    elif row["exploit_maturity"] == 3:
        score += 0.5
    else: 
        score += 0.25

    return score

# %%
number_of_train_groups = 1000
number_of_validation_groups = 100
max_number_of_cves = 500
min_number_of_cves = 100

train_dataset_list = []
val_dataset_list = []
demo_dataset = data_copy.sample(200)

for group_number in range(number_of_train_groups + number_of_validation_groups):
    number_of_cves = random.randint(min_number_of_cves, max_number_of_cves)
    random_rows = data_copy.sample(n=number_of_cves)
    random_rows["priority_score"] = random_rows.apply(generate_priority_score, current_data=data_copy, axis=1)
    random_rows = random_rows.sort_values(by="priority_score", ascending=False)
    random_rows["group_id"] = group_number+1

    if (group_number+1) > (number_of_train_groups):
        val_dataset_list.append(random_rows)
    else:
        train_dataset_list.append(random_rows)

    print(random_rows.head(n=5))

train_dataset = pd.concat(train_dataset_list)
val_dataset = pd.concat(val_dataset_list)
# Out:
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 76190  CVE-2021-43778            1.0                0.0                  NaN
# 35826  CVE-2023-37231            1.0                0.0                  NaN
# 93668  CVE-2021-21856            1.0                0.0                  NaN
# 91951  CVE-2021-23855            1.0                0.0                  NaN
# 68610  CVE-2022-27178            3.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 76190                  2.0               0.0               NaN  0.52469
# 35826                  2.0               0.0               NaN  0.00045
# 93668                  2.0               1.0               NaN  0.00307
# 91951                  2.0               0.0               NaN  0.00168
# 68610                  2.0               0.0               NaN  0.00283
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 76190     0.97623         9.1            1.0                 1123
# 35826     0.16337         9.8            1.0                  533
# 93668     0.70126         8.8            2.0                 1439
# 91951     0.54167         8.6            2.0                 1431
# 68610     0.68918         9.6            1.0                  996
#
#        days_since_published  date_reserved_published_delta  priority_score  \
#
1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 69259                  NaN               NaN               NaN  0.79689
# 33948                  NaN               NaN               NaN  0.68080
# 67550                  2.0               1.0               0.0  0.00127
# 46094                  2.0               0.0               NaN  0.00128
# 20808                  2.0               1.0               NaN  0.00075
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 69259     0.98337         9.8            1.0                 1008
# 33948     0.98012         NaN            NaN                  507
# 67550     0.48076         7.8            2.0                  979
# 46094     0.48323        10.0            1.0                  666
# 20808     0.33267         8.8            2.0                  336
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 69259                   947                             61       51.046070
# 33948                   480                             27       29.159194
# 67550                   458                            521       14.728978
# 46094                   659                              7       12.266481
# 20808                   171                            165       11.961279
#
#        group_id
# 69259         5
# 33948         5
# 67550         5
# 46094         5
# 20808         5
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 85653  CVE-2021-32305            NaN                NaN                  NaN
# 84835  CVE-2021-33554            1.0                0.0                  NaN
# 22700   CVE-2023-6989            NaN                NaN                  NaN
# 36500  CVE-2023-36177            1.0                0.0                  NaN
# 76412  CVE-2022-21613            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 85653                  NaN               NaN               NaN  0.94875
# 84835                  1.0               0.0               NaN  0.97077
# 22700                  NaN               NaN               NaN  0.24154
# 36500                  2.0               0.0               NaN  0.00380
# 76412                  2.0               1.0               NaN  0.00357
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 85653     0.99324         NaN            NaN                 1316
# 84835     0.99809         7.2            2.0                 1299
# 22700     0.96684         9.8            1.0                  358
# 36500     0.73235         9.8            1.0                  541
# 76412     0.72393         8.8            2.0                 1124
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 85653                  1304                             12       61.792853
# 84835                  1186                            113       61.538600
# 22700                   311                             47       23.123983
# 36500                   325                            216       14.354630
# 76412                   787                            337       14.231390
#
#        group_id
# 85653         6
# 84835         6
# 22700         6
# 36500         6
# 76412         6
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 93536  CVE-2021-21803            1.0                0.0                  NaN
# 80000  CVE-2021-40379            NaN                NaN                  NaN
# 76044  CVE-2021-44077            NaN                NaN                  NaN
# 46829  CVE-2023-25157            1.0                0.0                  NaN
# 73162  CVE-2022-23125            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 93536                  2.0               1.0               NaN  0.80818
# 80000                  NaN               NaN               NaN  0.74695
# 76044                  NaN               NaN               NaN  0.97404
# 46829                  2.0               0.0               NaN  0.68065
# 73162                  2.0               0.0               NaN  0.04924
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 93536     0.98380         9.6            1.0                 1439
# 80000     0.98192         NaN            NaN                 1199
# 76044     0.99941         NaN            NaN                 1119
# 46829     0.98011         9.8            1.0                  678
# 73162     0.92961         9.8            1.0                 1067
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 93536                  1245                            194       63.741708
# 80000                  1198                              1       54.636529
# 76044                  1110                              9       52.054315
# 46829                   660                             18       36.887255
# 73162                   626                            441       16.746599
#
#        group_id
# 93536         7
# 80000         7
# 76044         7
# 46829         7
# 73162         7
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 93374  CVE-2021-21914            1.0                0.0                  NaN
# 77360  CVE-2022-20777            1.0                0.0                  NaN
# 36055  CVE-2023-36825            1.0                0.0                  NaN
# 68581  CVE-2022-27862            1.0                0.0                  NaN
# 23438   CVE-2023-6677            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 93374                  2.0               0.0               NaN  0.00271
# 77360                  0.0               0.0               NaN  0.00104
# 36055                  2.0               1.0               NaN  0.00883
# 68581                  2.0               0.0               NaN  0.00221
# 23438                  2.0               0.0               NaN  0.00091
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 33948                   480                             27       29.159194
# 93378                   973                            466       15.903810
# 23                       86                              1       14.507429
# 68210                   951                             38       11.902393
# 77142                   770                            366       11.606368
#
#        group_id
# 33948        11
# 93378        11
# 23           11
# 68210        11
# 77142        11
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 12124   CVE-2024-3400            1.0                0.0                  NaN
# 67546  CVE-2022-28836            2.0                0.0                  NaN
# 67550  CVE-2022-28832            2.0                0.0                  NaN
# 77479  CVE-2022-20695            1.0                0.0                  NaN
# 52430  CVE-2022-45794            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 12124                  2.0               0.0               NaN  0.96464
# 67546                  2.0               1.0               0.0  0.00482
# 67550                  2.0               1.0               0.0  0.00127
# 77479                  2.0               0.0               NaN  0.00455
# 52430                  2.0               0.0               NaN  0.00087
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 12124     0.99618        10.0            1.0                  251
# 67546     0.76166         7.8            2.0                  979
# 67550     0.48076         7.8            2.0                  979
# 77479     0.75496        10.0            1.0                 1137
# 52430     0.37654         8.6            2.0                  751
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 12124                   244                              7       23.365656
# 67546                   458                            521       15.448978
# 67550                   458                            521       14.728978
# 77479                   972                            165       14.136004
# 52430                   337                            414       13.821480
#
#        group_id
# 12124        12
# 67546        12
# 67550        12
# 77479        12
# 52430        12
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 79539  CVE-2021-40870            NaN                NaN                  NaN
# 40019  CVE-2023-32244            1.0                0.0                  NaN
# 44984  CVE-2023-27255            1.0                0.0                  NaN
# 75041  CVE-2022-22034            NaN                NaN                  NaN
# 60345   CVE-2022-2586            2.0                1.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 79539                  NaN               NaN               NaN  0.93851
# 40019                  2.0               0.0               NaN  0.00043
# 44984                  2.0               0.0               NaN  0.00113
# 75041                  NaN               NaN               NaN  0.33833
# 60345                  0.0               0.0               NaN  0.00842
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 79539     0.99190         NaN            NaN                 1187
# 40019     0.09608         9.8            1.0                  587
# 44984     0.45517         9.8            1.0                  654
# 75041     0.97141         7.8            2.0                 1093
# 60345     0.82380         5.3            3.0                  867
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 79539                  1186                              1       56.602029
# 40019                   209                            378       13.950671
# 44984                   414                            240       13.826636
# 75041                   884                            209       13.322924
# 60345                   339                            528       12.924334
#
#        group_id
# 79539        13
# 40019        13
# 44984        13
# 75041        13
# 60345        13
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 88720  CVE-2021-27905            NaN                NaN                  NaN
# 89128  CVE-2021-27258            1.0                0.0                  NaN
# 65412  CVE-2022-31125            1.0                0.0                  NaN
# 39889  CVE-2023-32314            1.0                0.0                  NaN
# 14248  CVE-2024-29725            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 88720                  NaN               NaN               NaN  0.94751
# 89128                  2.0               0.0               NaN  0.02704
# 65412                  2.0               0.0               NaN  0.02196
# 39889                  2.0               0.0               NaN  0.01622
# 14248                  2.0               0.0               NaN  0.00091
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 88720     0.99300         NaN            NaN                 1382
# 89128     0.90670         9.8            1.0                 1396
# 65412     0.89623        10.0            1.0                  940
# 39889     0.87754         9.8            1.0                  584
# 14248     0.39616         9.8            1.0                  268
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 88720                  1339                             43       62.009565
# 89128                  1338                             58       13.732856
# 65412                   891                             49       13.714417
# 39889                   577                              7       13.226956
# 14248                   105                            163       13.105946
#
#        group_id
# 88720        14
# 89128        14
# 65412        14
# 39889        14
# 14248        14
#                   cve  attack_vector  attack_complexity  attack_requirements  \
#
  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 86424                  NaN               NaN               NaN  0.86146
# 88682                  NaN               NaN               NaN  0.55407
# 70232                  2.0               0.0               NaN      NaN
# 38920                  2.0               0.0               NaN  0.19437
# 27429                  NaN               NaN               NaN  0.68808
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 86424     0.98615         7.8            2.0                 1339
# 88682     0.97698         NaN            NaN                 1381
# 70232         NaN         7.8            2.0                 1024
# 38920     0.96376        10.0            1.0                  573
# 27429     0.98032         NaN            NaN                  413
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 86424                  1311                             28       59.630699
# 88682                  1380                              1       57.683029
# 70232                    85                            939       55.776226
# 38920                   567                              6       29.425827
# 27429                   413                              0       24.032400
#
#        group_id
# 86424        18
# 88682        18
# 70232        18
# 38920        18
# 27429        18
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 93536  CVE-2021-21803            1.0                0.0                  NaN
# 86233  CVE-2021-31474            1.0                0.0                  NaN
# 93544  CVE-2021-21821            1.0                0.0                  NaN
# 92040  CVE-2021-23460            1.0                0.0                  NaN
# 89948  CVE-2021-26097            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 93536                  2.0               1.0               NaN  0.80818
# 86233                  2.0               0.0               NaN  0.62580
# 93544                  2.0               0.0               NaN  0.00573
# 92040                  2.0               0.0               1.0  0.00672
# 89948                  0.0               0.0               3.0  0.00239
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 93536     0.98380         9.6            1.0                 1439
# 86233     0.97885         9.8            1.0                 1337
# 93544     0.78169         9.8            1.0                 1439
# 92040     0.80041         7.5            2.0                 1435
# 89948     0.62063         8.8            2.0                 1418
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 93536                  1245                            194       63.741708
# 86233                  1301                             36       61.743584
# 93544                  1253                            186       14.264747
# 92040                  1056                            379       14.100375
# 89948                  1226                            192       13.889974
#
#        group_id
# 93536        19
# 86233        19
# 93544        19
# 92040        19
# 89948        19
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 88622  CVE-2021-28052            1.0                1.0                  NaN
# 84533  CVE-2021-33841            1.0                0.0                  NaN
# 26025   CVE-2023-6153            1.0                0.0                  NaN
# 21696  CVE-2024-21899            1.0                0.0                  NaN
# 31997   CVE-2023-4494            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 88622                  0.0               0.0               NaN  0.00065
# 84533                  2.0               0.0               NaN  0.00605
# 26025                  2.0               0.0               NaN  0.00091
# 21696                  2.0               0.0               NaN  0.00130
# 31997                  2.0               0.0               NaN  0.00156
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 88622     0.29190         7.5            2.0                 1377
# 84533     0.78788        10.0            1.0                 1288
# 26025     0.39616         9.8            1.0                  393
# 21696     0.48583         9.8            1.0                  345
# 31997     0.52408         9.8            1.0                  477
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 88622                   808                            569       13.960340
# 84533                  1282                              6       13.044527
# 26025                   260                            133       12.883063
# 21696                   279                             66       12.611417
# 31997                   435                             42       12.530036
#
#        group_id
# 88622        20
# 84533        20
# 26025        20
# 21696        20
# 31997        20
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 93340  CVE-2021-21975            NaN                NaN                  NaN
# 30153  CVE-2023-43177            NaN                NaN                  NaN
# 49524  CVE-2023-22582            1.0                0.0                  NaN
# 93565  CVE-2021-21830            1.0                1.0                  NaN
# 25414   CVE-2023-6229            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 93340                  NaN               NaN               NaN  0.97338
# 30153                  NaN               NaN               NaN  0.96148
# 49524                  0.0               1.0               NaN  0.00107
# 93565                  2.0               0.0               NaN  0.00649
# 25414                  2.0               0.0               NaN  0.00129
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
#
1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 75004                  NaN               NaN               NaN  0.95998
# 85537                  2.0               0.0               NaN  0.00142
# 944                    2.0               0.0               NaN      NaN
# 92616                  1.0               0.0               NaN  0.00043
# 85207                  2.0               0.0               NaN  0.01163
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 75004     0.99518         NaN            NaN                 1093
# 85537     0.50618        10.0            1.0                 1312
# 944           NaN         9.8            1.0                  114
# 92616     0.09608         7.2            2.0                 1437
# 85207     0.85167         9.8            1.0                 1310
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 75004                  1090                              3       51.847988
# 85537                   524                            788       18.126933
# 944                      86                             28       18.008024
# 92616                   209                           1228       17.715678
# 85207                  1151                            159       14.268603
#
#        group_id
# 75004      1098
# 85537      1098
# 944        1098
# 92616      1098
# 85207      1098
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 60224  CVE-2022-37061            NaN                NaN                  NaN
# 64538   CVE-2022-1952            NaN                NaN                  NaN
# 87998  CVE-2021-29050            1.0                0.0                  NaN
# 92041  CVE-2021-23463            1.0                0.0                  NaN
# 88968  CVE-2021-27431            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 60224                  NaN               NaN               NaN  0.97481
# 64538                  NaN               NaN               NaN  0.72225
# 87998                  2.0               1.0               NaN  0.00043
# 92041                  0.0               0.0               1.0  0.01036
# 88968                  2.0               0.0               NaN  0.00248
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 60224     0.99976         NaN            NaN                  865
# 64538     0.98130         NaN            NaN                  927
# 87998     0.09608         8.8            2.0                 1362
# 92041     0.84153         8.1            2.0                 1435
# 88968     0.64981         7.3            2.0                 1393
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 60224                   848                             17       47.123200
# 64538                   885                             42       44.691036
# 87998                   297                           1065       18.054683
# 92041                  1098                            337       14.459340
# 88968                   954                            439       14.048441
#
#        group_id
# 60224      1099
# 64538      1099
# 87998      1099
# 92041      1099
# 88968      1099
#                   cve  attack_vector  attack_complexity  attack_requirements  \
# 77367  CVE-2022-20770            1.0                0.0                  NaN
# 78768  CVE-2021-42079            1.0                0.0                  NaN
# 28567  CVE-2023-45616            1.0                0.0                  NaN
# 27230  CVE-2023-47117            1.0                0.0                  NaN
# 59695   CVE-2022-2733            1.0                0.0                  NaN
#
#        privileges_required  user_interaction  exploit_maturity     epss  \
# 77367                  2.0               0.0               NaN  0.01620
# 78768                  1.0               1.0               NaN  0.00124
# 28567                  2.0               0.0               NaN  0.00191
# 27230                  2.0               0.0               NaN  0.12952
# 59695                  2.0               1.0               NaN  0.00167
#
#        percentile  cvss_score  cvss_severity  days_since_reserved  \
# 77367     0.87743         8.6            2.0                 1137
# 78768     0.47506         6.2            3.0                 1162
# 28567     0.56923         9.8            1.0                  430
# 27230     0.95608         7.5            2.0                  409
# 59695     0.53823         9.6            1.0                  857
#
#        days_since_published  date_reserved_published_delta  priority_score  \
# 77367                   953                            184       13.441588
# 78768                   521                            641       13.306109
# 28567                   394                             36       12.600084
# 27230                   395                             14       12.391812
# 59695                   856                              1       12.161354
#
#        group_id
# 77367      1100
# 78768      1100
# 28567      1100
# 27230      1100
# 59695      1100

# %%
train_dataset.to_csv("daan881_group4_dataset.train.csv", index=False)
val_dataset.to_csv("daan881_group4_dataset.val.csv", index=False)
demo_dataset.to_csv("daan881_group4_dataset.demo.csv", index=False)
